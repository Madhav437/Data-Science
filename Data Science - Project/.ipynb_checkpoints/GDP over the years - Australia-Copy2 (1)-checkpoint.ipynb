# %%
import wbdata
import pandas as pd
import pycountry
import wbdata
import datetime
import matplotlib.pyplot as plt

 

countries = ["AUS"]

indicators1 = { 
               'BX.KLT.DINV.WD.GD.ZS': 'FDI net inflows', 
               'BM.KLT.DINV.WD.GD.ZS':'FDI net outflows', 
              'SH.XPD.GHED.GD.ZS': 'Domestic health expenditure',
              'GC.XPN.TOTL.GD.ZS': 'Expense on Goods & Services',
              'NE.CON.TOTL.ZS': 'Final consumption expenditure',
                'NV.AGR.TOTL.ZS' : 'Agriculture,forestry,fishing',
               #'SE.ADT.LITR.ZS' : 'Literacy rate',
             'SE.XPD.TOTL.GD.ZS' : 'Edu Exp',
           'GB.XPD.RSDV.GD.ZS' : 'Research and development expenditure'
              }

data_date = (datetime.datetime(1985, 1, 1), datetime.datetime(2015, 1, 1))
 
 
df1 = wbdata.get_dataframe(indicators1, country=countries, data_date=data_date ,convert_date=False)

# %%
df1.insert(0, "Country code","AUS")
df1
# Out:
#      Country code  FDI net inflows  FDI net outflows  \
# date
# 2015          AUS         3.469188          0.610997
# 2014          AUS         4.306384          1.537726
# 2013          AUS         3.425824         -0.048833
# 2012          AUS         3.722172          0.372774
# 2011          AUS         4.693724          0.590745
# 2010          AUS         3.072119          1.576474
# 2009          AUS         3.091518          1.235587
# 2008          AUS         4.284650          3.025409
# 2007          AUS         5.209250          1.690398
# 2006          AUS         4.095024          3.227987
# 2005          AUS        -3.618815         -4.717772
# 2004          AUS         7.005444          1.597584
# 2003          AUS         1.926147          3.986776
# 2002          AUS         3.713762          1.767229
# 2001          AUS         2.832402          3.536383
# 2000          AUS         3.586745          0.986223
# 1999          AUS         0.568932          0.080123
# 1998          AUS         1.904645          1.169882
# 1997          AUS         1.861175          1.399583
# 1996          AUS         1.140125          1.250652
# 1995          AUS         3.613367          1.101707
# 1994          AUS         1.383713          0.567272
# 1993          AUS         1.705194          0.817151
# 1992          AUS         1.521154          1.180546
# 1991          AUS         0.802946         -0.360288
# 1990          AUS         2.721492          0.203708
# 1989          AUS         2.680932          1.010623
# 1988          AUS         3.596879          3.596879
# 1987          AUS         2.745431          2.745431
# 1986          AUS         2.949819          2.949819
# 1985          AUS         1.164384          1.164384
#
#       Domestic health expenditure  Expense on Goods & Services  \
# date
# 2015                     6.353409                    26.756354
# 2014                     6.087821                    26.270761
# 2013                     5.916563                    25.896647
# 2012                     5.859168                    26.143046
# 2011                     5.911898                    26.031856
# 2010                     5.786625                    26.768833
# 2009                     5.933924                    26.493777
# 2008                     5.696407                    24.370410
# 2007                     5.591425                    24.501630
# 2006                     5.457375                    24.977871
# 2005                     5.465395                    25.639466
# 2004                     5.542416                    25.696281
# 2003                     5.379015                    25.773322
# 2002                     5.416837                    26.433438
# 2001                     5.214668                    26.264917
# 2000                     5.206260                    24.083919
# 1999                          NaN                    24.567800
# 1998                          NaN                    21.368584
# 1997                          NaN                    23.864424
# 1996                          NaN                    24.627037
# 1995                          NaN                    25.451557
# 1994                          NaN                    25.138431
# 1993                          NaN                    25.016126
# 1992                          NaN                    24.485134
# 1991                          NaN                    23.213295
# 1990                          NaN                    21.861559
# 1989                          NaN                    22.229145
# 1988                          NaN                    24.248356
# 1987                          NaN                    25.751817
# 1986                          NaN                    26.190055
# 1985                          NaN                    26.483155
#
#       Final consumption expenditure  Agriculture,forestry,fishing  Edu Exp  \
# date
# 2015                      75.253985                      2.372644  5.31196
# 2014                      73.681945                      2.216224  5.16477
# 2013                      73.400238                      2.278906  5.22974
# 2012                      72.506066                      2.254748  4.86900
# 2011                      72.526546                      2.276542  5.07451
# 2010                      74.178362                      2.197568  5.55006
# 2009                      72.392225                      2.291720  5.08582
# 2008                      73.882561                      2.338630  4.63776
# 2007                      74.072813                      2.201100  4.66089
# 2006                      74.211836                      2.726734  4.75020
# 2005                      75.182004                      2.883330  4.91030
# 2004                      75.542107                      3.062114      NaN
# 2003                      76.089568                      2.888534      NaN
# 2002                      75.514980                      3.948012      NaN
# 2001                      76.433979                      3.503360      NaN
# 2000                      75.851648                      3.119068  4.89147
# 1999                      76.232502                      3.061401      NaN
# 1998                      75.188277                      3.038954      NaN
# 1997                      74.808524                      3.243344      NaN
# 1996                      75.602683                      3.392160  5.24097
# 1995                      75.920755                      3.021633  5.14391
# 1994                      76.050816                      3.349171  5.25482
# 1993                      77.165250                      3.263718  5.51661
# 1992                      77.975097                      3.053451  4.69247
# 1991                      75.390974                      3.182316  4.79483
# 1990                      72.404700                      4.209184  4.67640
# 1989                      71.878018                           NaN  4.74911
# 1988                      73.452098                           NaN  4.91834
# 1987                      75.787517                           NaN  5.06990
# 1986                      75.377728                           NaN  5.28061
# 1985                      74.184584                           NaN  5.40543
#
#       Research and development expenditure
# date
# 2015                               1.91943
# 2014                                   NaN
# 2013                               2.17870
# 2012                                   NaN
# 2011                               2.23765
# 2010                               2.37586
# 2009                                   NaN
# 2008                               2.40370
# 2007                                   NaN
# 2006                               2.18552
# 2005                                   NaN
# 2004                               1.85456
# 2003                                   NaN
# 2002                               1.75161
# 2001                                   NaN
# 2000                               1.57558
# 1999                                   NaN
# 1998                               1.51645
# 1997                                   NaN
# 1996                               1.66650
# 1995                                   NaN
# 1994                                   NaN
# 1993                                   NaN
# 1992                                   NaN
# 1991                                   NaN
# 1990                                   NaN
# 1989                                   NaN
# 1988                                   NaN
# 1987                                   NaN
# 1986                                   NaN
# 1985                                   NaN

# %%
df1.reset_index(inplace = True)

# %%
df1['Research and development expenditure'] = df1['Research and development expenditure'].interpolate(method = 'polynomial', order = 2)
df1['Research and development expenditure'] = df1['Research and development expenditure'].interpolate(method = 'pad')

# %%
df1
# Out:
#     date Country code  FDI net inflows  FDI net outflows  \
# 0   2015          AUS         3.469188          0.610997
# 1   2014          AUS         4.306384          1.537726
# 2   2013          AUS         3.425824         -0.048833
# 3   2012          AUS         3.722172          0.372774
# 4   2011          AUS         4.693724          0.590745
# 5   2010          AUS         3.072119          1.576474
# 6   2009          AUS         3.091518          1.235587
# 7   2008          AUS         4.284650          3.025409
# 8   2007          AUS         5.209250          1.690398
# 9   2006          AUS         4.095024          3.227987
# 10  2005          AUS        -3.618815         -4.717772
# 11  2004          AUS         7.005444          1.597584
# 12  2003          AUS         1.926147          3.986776
# 13  2002          AUS         3.713762          1.767229
# 14  2001          AUS         2.832402          3.536383
# 15  2000          AUS         3.586745          0.986223
# 16  1999          AUS         0.568932          0.080123
# 17  1998          AUS         1.904645          1.169882
# 18  1997          AUS         1.861175          1.399583
# 19  1996          AUS         1.140125          1.250652
# 20  1995          AUS         3.613367          1.101707
# 21  1994          AUS         1.383713          0.567272
# 22  1993          AUS         1.705194          0.817151
# 23  1992          AUS         1.521154          1.180546
# 24  1991          AUS         0.802946         -0.360288
# 25  1990          AUS         2.721492          0.203708
# 26  1989          AUS         2.680932          1.010623
# 27  1988          AUS         3.596879          3.596879
# 28  1987          AUS         2.745431          2.745431
# 29  1986          AUS         2.949819          2.949819
# 30  1985          AUS         1.164384          1.164384
#
#     Domestic health expenditure  Expense on Goods & Services  \
# 0                      6.353409                    26.756354
# 1                      6.087821                    26.270761
# 2                      5.916563                    25.896647
# 3                      5.859168                    26.143046
# 4                      5.911898                    26.031856
# 5                      5.786625                    26.768833
# 6                      5.933924                    26.493777
# 7                      5.696407                    24.370410
# 8                      5.591425                    24.501630
# 9                      5.457375                    24.977871
# 10                     5.465395                    25.639466
# 11                     5.542416                    25.696281
# 12                     5.379015                    25.773322
# 13                     5.416837                    26.433438
# 14                     5.214668                    26.264917
# 15                     5.206260                    24.083919
# 16                          NaN                    24.567800
# 17                          NaN                    21.368584
# 18                          NaN                    23.864424
# 19                          NaN                    24.627037
# 20                          NaN                    25.451557
# 21                          NaN                    25.138431
# 22                          NaN                    25.016126
# 23                          NaN                    24.485134
# 24                          NaN                    23.213295
# 25                          NaN                    21.861559
# 26                          NaN                    22.229145
# 27                          NaN                    24.248356
# 28                          NaN                    25.751817
# 29                          NaN                    26.190055
# 30                          NaN                    26.483155
#
#     Final consumption expenditure  Agriculture,forestry,fishing  Edu Exp  \
# 0                       75.253985                      2.372644  5.31196
# 1                       73.681945                      2.216224  5.16477
# 2                       73.400238                      2.278906  5.22974
# 3                       72.506066                      2.254748  4.86900
# 4                       72.526546                      2.276542  5.07451
# 5                       74.178362                      2.197568  5.55006
# 6                       72.392225                      2.291720  5.08582
# 7                       73.882561                      2.338630  4.63776
# 8                       74.072813                      2.201100  4.66089
# 9                       74.211836                      2.726734  4.75020
# 10                      75.182004                      2.883330  4.91030
# 11                      75.542107                      3.062114      NaN
# 12                      76.089568                      2.888534      NaN
# 13                      75.514980                      3.948012      NaN
# 14                      76.433979                      3.503360      NaN
# 15                      75.851648                      3.119068  4.89147
# 16                      76.232502                      3.061401      NaN
# 17                      75.188277                      3.038954      NaN
# 18                      74.808524                      3.243344      NaN
# 19                      75.602683                      3.392160  5.24097
# 20                      75.920755                      3.021633  5.14391
# 21                      76.050816                      3.349171  5.25482
# 22                      77.165250                      3.263718  5.51661
# 23                      77.975097                      3.053451  4.69247
# 24                      75.390974                      3.182316  4.79483
# 25                      72.404700                      4.209184  4.67640
# 26                      71.878018                           NaN  4.74911
# 27                      73.452098                           NaN  4.91834
# 28                      75.787517                           NaN  5.06990
# 29                      75.377728                           NaN  5.28061
# 30                      74.184584                           NaN  5.40543
#
#     Research and development expenditure
# 0                               1.919430
# 1                               2.086669
# 2                               2.178700
# 3                               2.195524
# 4                               2.237650
# 5                               2.375860
# 6                               2.431805
# 7                               2.403700
# 8                               2.319484
# 9                               2.185520
# 10                              2.008171
# 11                              1.854560
# 12                              1.791809
# 13                              1.751610
# 14                              1.665653
# 15                              1.575580
# 16                              1.523032
# 17                              1.516450
# 18                              1.564273
# 19                              1.666500
# 20                              1.666500
# 21                              1.666500
# 22                              1.666500
# 23                              1.666500
# 24                              1.666500
# 25                              1.666500
# 26                              1.666500
# 27                              1.666500
# 28                              1.666500
# 29                              1.666500
# 30                              1.666500

# %%
df1['Domestic health expenditure'].interpolate(method = 'pad')

df1['Agriculture,forestry,fishing'].interpolate(method = 'pad')
# Out:
# 0     2.372644
# 1     2.216224
# 2     2.278906
# 3     2.254748
# 4     2.276542
# 5     2.197568
# 6     2.291720
# 7     2.338630
# 8     2.201100
# 9     2.726734
# 10    2.883330
# 11    3.062114
# 12    2.888534
# 13    3.948012
# 14    3.503360
# 15    3.119068
# 16    3.061401
# 17    3.038954
# 18    3.243344
# 19    3.392160
# 20    3.021633
# 21    3.349171
# 22    3.263718
# 23    3.053451
# 24    3.182316
# 25    4.209184
# 26    4.209184
# 27    4.209184
# 28    4.209184
# 29    4.209184
# 30    4.209184
# Name: Agriculture,forestry,fishing, dtype: float64

# %%
df1['Edu Exp'].interpolate(method = 'polynomial', order = 2)
# Out:
# 0     5.311960
# 1     5.164770
# 2     5.229740
# 3     4.869000
# 4     5.074510
# 5     5.550060
# 6     5.085820
# 7     4.637760
# 8     4.660890
# 9     4.750200
# 10    4.910300
# 11    4.999910
# 12    4.992385
# 13    4.907904
# 14    4.867540
# 15    4.891470
# 16    4.979695
# 17    5.132215
# 18    5.251737
# 19    5.240970
# 20    5.143910
# 21    5.254820
# 22    5.516610
# 23    4.692470
# 24    4.794830
# 25    4.676400
# 26    4.749110
# 27    4.918340
# 28    5.069900
# 29    5.280610
# 30    5.405430
# Name: Edu Exp, dtype: float64

# %%
df1['Research and development expenditure'] = 1.919430,2.086668,2.178700,2.195525,2.237650,2.375860,2.431817,2.403700,2.319410,2.185520,2.008604,1.854560,1.789283,1.751610,1.680376,1.575580
df1['Edu Exp'] = 5.311960,5.164770,5.229740,4.869000,5.074510,5.550060,5.085820,4.637760,4.660890,4.750200,4.910300,5.030089,5.088101,5.084335,5.018791,4.891470
df1
# Out:
#     date Country code  FDI net inflows  FDI net outflows  \
# 0   2015          AUS         3.469188          0.610997
# 1   2014          AUS         4.306384          1.537726
# 2   2013          AUS         3.425824         -0.048833
# 3   2012          AUS         3.722172          0.372774
# 4   2011          AUS         4.693724          0.590745
# 5   2010          AUS         3.072119          1.576474
# 6   2009          AUS         3.091518          1.235587
# 7   2008          AUS         4.284650          3.025409
# 8   2007          AUS         5.209250          1.690398
# 9   2006          AUS         4.095024          3.227987
# 10  2005          AUS        -3.618815         -4.717772
# 11  2004          AUS         7.005444          1.597584
# 12  2003          AUS         1.926147          3.986776
# 13  2002          AUS         3.713762          1.767229
# 14  2001          AUS         2.832402          3.536383
# 15  2000          AUS         3.586745          0.986223
#
#     Domestic health expenditure  Expense on Goods & Services  \
# 0                      6.353409                    26.756354
# 1                      6.087821                    26.270761
# 2                      5.916563                    25.896647
# 3                      5.859168                    26.143046
# 4                      5.911898                    26.031856
# 5                      5.786625                    26.768833
# 6                      5.933924                    26.493777
# 7                      5.696407                    24.370410
# 8                      5.591425                    24.501630
# 9                      5.457375                    24.977871
# 10                     5.465395                    25.639466
# 11                     5.542416                    25.696281
# 12                     5.379015                    25.773322
# 13                     5.416837                    26.433438
# 14                     5.214668                    26.264917
# 15                     5.206260                    24.083919
#
#     Final consumption expenditure  Agriculture,forestry,fishing   Edu Exp  \
# 0                       75.253985                      2.372644  5.311960
# 1                       73.681945                      2.216224  5.164770
# 2                       73.400238                      2.278906  5.229740
# 3                       72.506066                      2.254748  4.869000
# 4                       72.526546                      2.276542  5.074510
# 5                       74.178362                      2.197568  5.550060
# 6                       72.392225                      2.291720  5.085820
# 7                       73.882561                      2.338630  4.637760
# 8                       74.072813                      2.201100  4.660890
# 9                       74.211836                      2.726734  4.750200
# 10                      75.182004                      2.883330  4.910300
# 11                      75.542107                      3.062114  5.030089
# 12                      76.089568                      2.888534  5.088101
# 13                      75.514980                      3.948012  5.084335
# 14                      76.433979                      3.503360  5.018791
# 15                      75.851648                      3.119068  4.891470
#
#     Research and development expenditure
# 0                               1.919430
# 1                               2.086668
# 2                               2.178700
# 3                               2.195525
# 4                               2.237650
# 5                               2.375860
# 6                               2.431817
# 7                               2.403700
# 8                               2.319410
# 9                               2.185520
# 10                              2.008604
# 11                              1.854560
# 12                              1.789283
# 13                              1.751610
# 14                              1.680376
# 15                              1.575580

# %%
data_date = (datetime.datetime(2000, 1, 1), datetime.datetime(2015, 1, 1))
indicators2 = {'NY.GDP.PCAP.CD': 'GDP per Capita'}

# %%
df = wbdata.get_dataframe(indicators2, country=countries, data_date=data_date ,convert_date=False)
df
# Out:
#       GDP per Capita
# date
# 2015    56755.721712
# 2014    62510.791171
# 2013    68150.107041
# 2012    68012.147901
# 2011    62517.833747
# 2010    52022.125596
# 2009    42772.359166
# 2008    49601.656708
# 2007    40960.054495
# 2006    36044.922811
# 2005    33999.242858
# 2004    30430.676437
# 2003    23447.031001
# 2002    20082.483267
# 2001    19490.861110
# 2000    21679.247842

# %%
df.reset_index(inplace = True)

# %%
df = df.drop(['date'],axis = 1)
df
# Out:
#     GDP per Capita
# 0     56755.721712
# 1     62510.791171
# 2     68150.107041
# 3     68012.147901
# 4     62517.833747
# 5     52022.125596
# 6     42772.359166
# 7     49601.656708
# 8     40960.054495
# 9     36044.922811
# 10    33999.242858
# 11    30430.676437
# 12    23447.031001
# 13    20082.483267
# 14    19490.861110
# 15    21679.247842

# %%
#grab indicators above for countires above and load into data frame
#df = wbdata.get_dataframe(indicators, country=countries, data_date=data_date ,convert_date=False)

data_date = (datetime.datetime(2002, 1, 1), datetime.datetime(2017, 1, 1))
indicators2 = {'NY.GDP.PCAP.CD': 'GDP per Capita after 2 years'}

# %%
#grab indicators above for countires above and load into data frame
df2 = wbdata.get_dataframe(indicators2, country=countries, data_date=data_date ,convert_date=False)

# %%
df2
# Out:
#       GDP per Capita after 2 years
# date
# 2017                  54066.471269
# 2016                  49971.131456
# 2015                  56755.721712
# 2014                  62510.791171
# 2013                  68150.107041
# 2012                  68012.147901
# 2011                  62517.833747
# 2010                  52022.125596
# 2009                  42772.359166
# 2008                  49601.656708
# 2007                  40960.054495
# 2006                  36044.922811
# 2005                  33999.242858
# 2004                  30430.676437
# 2003                  23447.031001
# 2002                  20082.483267

# %%
df2.reset_index(inplace = True)

# %%
df2 = df2.drop(['date'],axis = 1)

# %%
df2
# Out:
#     GDP per Capita after 2 years
# 0                   54066.471269
# 1                   49971.131456
# 2                   56755.721712
# 3                   62510.791171
# 4                   68150.107041
# 5                   68012.147901
# 6                   62517.833747
# 7                   52022.125596
# 8                   42772.359166
# 9                   49601.656708
# 10                  40960.054495
# 11                  36044.922811
# 12                  33999.242858
# 13                  30430.676437
# 14                  23447.031001
# 15                  20082.483267

# %%
#Get GDP after 3 years

data_date = (datetime.datetime(2003, 1, 1), datetime.datetime(2018, 1, 1))

#grab indicators above for countires above and load into data frame
#df3 = wbdata.get_dataframe(indicators, country=countries, data_date=data_date ,convert_date=False)

indicators3 = {'NY.GDP.PCAP.CD': 'GDP per Capita after 3 years'}

# %%
#grab indicators above for countires above and load into data frame
df3 = wbdata.get_dataframe(indicators3, country=countries, data_date=data_date ,convert_date=False)

# %%
df3.reset_index(inplace = True)

# %%
df3 = df3.drop(['date'],axis = 1)

# %%
#Get GDP after 4 years

data_date = (datetime.datetime(2004, 1, 1), datetime.datetime(2019, 1, 1))



indicators4 = {'NY.GDP.PCAP.CD': 'GDP per Capita after 4 years'}

# %%
#grab indicators above for countires above and load into data frame
df4 = wbdata.get_dataframe(indicators4, country=countries, data_date=data_date ,convert_date=False)

# %%
df4.reset_index(inplace = True)

# %%
df4 = df4.drop(['date'],axis = 1)

# %%
df3
# Out:
#     GDP per Capita after 3 years
# 0                   57373.686684
# 1                   54066.471269
# 2                   49971.131456
# 3                   56755.721712
# 4                   62510.791171
# 5                   68150.107041
# 6                   68012.147901
# 7                   62517.833747
# 8                   52022.125596
# 9                   42772.359166
# 10                  49601.656708
# 11                  40960.054495
# 12                  36044.922811
# 13                  33999.242858
# 14                  30430.676437
# 15                  23447.031001

# %%
df4
# Out:
#     GDP per Capita after 4 years
# 0                            NaN
# 1                   57373.686684
# 2                   54066.471269
# 3                   49971.131456
# 4                   56755.721712
# 5                   62510.791171
# 6                   68150.107041
# 7                   68012.147901
# 8                   62517.833747
# 9                   52022.125596
# 10                  42772.359166
# 11                  49601.656708
# 12                  40960.054495
# 13                  36044.922811
# 14                  33999.242858
# 15                  30430.676437

# %%
# replacing na values in college with No college 
#nba["College"].fillna("No College", inplace = True)
df4 = df4["GDP per Capita after 4 years"].fillna("57373.7")

# %%
df_joined = pd.merge(df1,df3,left_index=True, right_index=True)
df_joined
# Out:
#     date Country code  FDI net inflows  FDI net outflows  \
# 0   2015          AUS         3.469188          0.610997
# 1   2014          AUS         4.306384          1.537726
# 2   2013          AUS         3.425824         -0.048833
# 3   2012          AUS         3.722172          0.372774
# 4   2011          AUS         4.693724          0.590745
# 5   2010          AUS         3.072119          1.576474
# 6   2009          AUS         3.091518          1.235587
# 7   2008          AUS         4.284650          3.025409
# 8   2007          AUS         5.209250          1.690398
# 9   2006          AUS         4.095024          3.227987
# 10  2005          AUS        -3.618815         -4.717772
# 11  2004          AUS         7.005444          1.597584
# 12  2003          AUS         1.926147          3.986776
# 13  2002          AUS         3.713762          1.767229
# 14  2001          AUS         2.832402          3.536383
# 15  2000          AUS         3.586745          0.986223
#
#     Domestic health expenditure  Expense on Goods & Services  \
# 0                      6.353409                    26.756354
# 1                      6.087821                    26.270761
# 2                      5.916563                    25.896647
# 3                      5.859168                    26.143046
# 4                      5.911898                    26.031856
# 5                      5.786625                    26.768833
# 6                      5.933924                    26.493777
# 7                      5.696407                    24.370410
# 8                      5.591425                    24.501630
# 9                      5.457375                    24.977871
# 10                     5.465395                    25.639466
# 11                     5.542416                    25.696281
# 12                     5.379015                    25.773322
# 13                     5.416837                    26.433438
# 14                     5.214668                    26.264917
# 15                     5.206260                    24.083919
#
#     Final consumption expenditure  Agriculture,forestry,fishing   Edu Exp  \
# 0                       75.253985                      2.372644  5.311960
# 1                       73.681945                      2.216224  5.164770
# 2                       73.400238                      2.278906  5.229740
# 3                       72.506066                      2.254748  4.869000
# 4                       72.526546                      2.276542  5.074510
# 5                       74.178362                      2.197568  5.550060
# 6                       72.392225                      2.291720  5.085820
# 7                       73.882561                      2.338630  4.637760
# 8                       74.072813                      2.201100  4.660890
# 9                       74.211836                      2.726734  4.750200
# 10                      75.182004                      2.883330  4.910300
# 11                      75.542107                      3.062114  5.030089
# 12                      76.089568                      2.888534  5.088101
# 13                      75.514980                      3.948012  5.084335
# 14                      76.433979                      3.503360  5.018791
# 15                      75.851648                      3.119068  4.891470
#
#     Research and development expenditure  GDP per Capita after 3 years
# 0                               1.919430                  57373.686684
# 1                               2.086668                  54066.471269
# 2                               2.178700                  49971.131456
# 3                               2.195525                  56755.721712
# 4                               2.237650                  62510.791171
# 5                               2.375860                  68150.107041
# 6                               2.431817                  68012.147901
# 7                               2.403700                  62517.833747
# 8                               2.319410                  52022.125596
# 9                               2.185520                  42772.359166
# 10                              2.008604                  49601.656708
# 11                              1.854560                  40960.054495
# 12                              1.789283                  36044.922811
# 13                              1.751610                  33999.242858
# 14                              1.680376                  30430.676437
# 15                              1.575580                  23447.031001

# %%
df_joined = pd.merge(df1,df4,left_index=True, right_index=True)
df_joined
# Out:
#     date Country code  FDI net inflows  FDI net outflows  \
# 0   2015          AUS         3.469188          0.610997
# 1   2014          AUS         4.306384          1.537726
# 2   2013          AUS         3.425824         -0.048833
# 3   2012          AUS         3.722172          0.372774
# 4   2011          AUS         4.693724          0.590745
# 5   2010          AUS         3.072119          1.576474
# 6   2009          AUS         3.091518          1.235587
# 7   2008          AUS         4.284650          3.025409
# 8   2007          AUS         5.209250          1.690398
# 9   2006          AUS         4.095024          3.227987
# 10  2005          AUS        -3.618815         -4.717772
# 11  2004          AUS         7.005444          1.597584
# 12  2003          AUS         1.926147          3.986776
# 13  2002          AUS         3.713762          1.767229
# 14  2001          AUS         2.832402          3.536383
# 15  2000          AUS         3.586745          0.986223
#
#     Domestic health expenditure  Expense on Goods & Services  \
# 0                      6.353409                    26.756354
# 1                      6.087821                    26.270761
# 2                      5.916563                    25.896647
# 3                      5.859168                    26.143046
# 4                      5.911898                    26.031856
# 5                      5.786625                    26.768833
# 6                      5.933924                    26.493777
# 7                      5.696407                    24.370410
# 8                      5.591425                    24.501630
# 9                      5.457375                    24.977871
# 10                     5.465395                    25.639466
# 11                     5.542416                    25.696281
# 12                     5.379015                    25.773322
# 13                     5.416837                    26.433438
# 14                     5.214668                    26.264917
# 15                     5.206260                    24.083919
#
#     Final consumption expenditure  Agriculture,forestry,fishing   Edu Exp  \
# 0                       75.253985                      2.372644  5.311960
# 1                       73.681945                      2.216224  5.164770
# 2                       73.400238                      2.278906  5.229740
# 3                       72.506066                      2.254748  4.869000
# 4                       72.526546                      2.276542  5.074510
# 5                       74.178362                      2.197568  5.550060
# 6                       72.392225                      2.291720  5.085820
# 7                       73.882561                      2.338630  4.637760
# 8                       74.072813                      2.201100  4.660890
# 9                       74.211836                      2.726734  4.750200
# 10                      75.182004                      2.883330  4.910300
# 11                      75.542107                      3.062114  5.030089
# 12                      76.089568                      2.888534  5.088101
# 13                      75.514980                      3.948012  5.084335
# 14                      76.433979                      3.503360  5.018791
# 15                      75.851648                      3.119068  4.891470
#
#     Research and development expenditure GDP per Capita after 4 years
# 0                               1.919430                      57373.7
# 1                               2.086668                      57373.7
# 2                               2.178700                      54066.5
# 3                               2.195525                      49971.1
# 4                               2.237650                      56755.7
# 5                               2.375860                      62510.8
# 6                               2.431817                      68150.1
# 7                               2.403700                      68012.1
# 8                               2.319410                      62517.8
# 9                               2.185520                      52022.1
# 10                              2.008604                      42772.4
# 11                              1.854560                      49601.7
# 12                              1.789283                      40960.1
# 13                              1.751610                      36044.9
# 14                              1.680376                      33999.2
# 15                              1.575580                      30430.7

# %%
df_joined1 = pd.merge(df_joined ,df3,left_index=True, right_index=True)

# %%
df_joined2 = pd.merge(df_joined1 ,df4,left_index=True, right_index=True)

# %%
df_joined2

# %%
# Normalizing the data in the rings column beacuse the value is too high when compared to independent variable

from sklearn import preprocessing

# Create x, where x the 'scores' column's values as floats
x = df_joined[['GDP per Capita after 4 years']].values.astype(float)

# Create a minimum and maximum processor object
min_max_scaler = preprocessing.MinMaxScaler()

# Create an object to transform the data to fit minmax processor
x_scaled = min_max_scaler.fit_transform(x)

# Run the normalizer on the dataframe
df_joined[['GDP per Capita after 4 years']] = pd.DataFrame(x_scaled)

# %%
df_joined.corr()
# Out:
#                                       FDI net inflows  FDI net outflows  \
# FDI net inflows                              1.000000          0.619189
# FDI net outflows                             0.619189          1.000000
# Domestic health expenditure                  0.180350         -0.208782
# Expense on Goods & Services                 -0.121748         -0.108949
# Final consumption expenditure               -0.196824          0.181356
# Agriculture,forestry,fishing                -0.131578          0.143347
# Edu Exp                                     -0.062530         -0.086321
# Research and development expenditure         0.109148         -0.077285
# GDP per Capita after 4 years                 0.282370          0.032006
#
#                                       Domestic health expenditure  \
# FDI net inflows                                          0.180350
# FDI net outflows                                        -0.208782
# Domestic health expenditure                              1.000000
# Expense on Goods & Services                              0.492128
# Final consumption expenditure                           -0.620497
# Agriculture,forestry,fishing                            -0.725966
# Edu Exp                                                  0.431539
# Research and development expenditure                     0.531085
# GDP per Capita after 4 years                             0.701956
#
#                                       Expense on Goods & Services  \
# FDI net inflows                                         -0.121748
# FDI net outflows                                        -0.108949
# Domestic health expenditure                              0.492128
# Expense on Goods & Services                              1.000000
# Final consumption expenditure                           -0.125922
# Agriculture,forestry,fishing                            -0.017068
# Edu Exp                                                  0.796827
# Research and development expenditure                     0.031136
# GDP per Capita after 4 years                             0.088812
#
#                                       Final consumption expenditure  \
# FDI net inflows                                           -0.196824
# FDI net outflows                                           0.181356
# Domestic health expenditure                               -0.620497
# Expense on Goods & Services                               -0.125922
# Final consumption expenditure                              1.000000
# Agriculture,forestry,fishing                               0.752722
# Edu Exp                                                    0.033774
# Research and development expenditure                      -0.834637
# GDP per Capita after 4 years                              -0.717389
#
#                                       Agriculture,forestry,fishing   Edu Exp  \
# FDI net inflows                                          -0.131578 -0.062530
# FDI net outflows                                          0.143347 -0.086321
# Domestic health expenditure                              -0.725966  0.431539
# Expense on Goods & Services                              -0.017068  0.796827
# Final consumption expenditure                             0.752722  0.033774
# Agriculture,forestry,fishing                              1.000000 -0.089404
# Edu Exp                                                  -0.089404  1.000000
# Research and development expenditure                     -0.799014 -0.063426
# GDP per Capita after 4 years                             -0.826697  0.050138
#
#                                       Research and development expenditure  \
# FDI net inflows                                                   0.109148
# FDI net outflows                                                 -0.077285
# Domestic health expenditure                                       0.531085
# Expense on Goods & Services                                       0.031136
# Final consumption expenditure                                    -0.834637
# Agriculture,forestry,fishing                                     -0.799014
# Edu Exp                                                          -0.063426
# Research and development expenditure                              1.000000
# GDP per Capita after 4 years                                      0.912589
#
#                                       GDP per Capita after 4 years
# FDI net inflows                                           0.282370
# FDI net outflows                                          0.032006
# Domestic health expenditure                               0.701956
# Expense on Goods & Services                               0.088812
# Final consumption expenditure                            -0.717389
# Agriculture,forestry,fishing                             -0.826697
# Edu Exp                                                   0.050138
# Research and development expenditure                      0.912589
# GDP per Capita after 4 years                              1.000000

# %%
import seaborn as sns
#plotting the heat map of the correlation
plt.figure(figsize=(20,7))
sns.heatmap(df_joined.corr(), annot=True)

# %%
df_joined
# Out:
#     date Country code  FDI net inflows  FDI net outflows  \
# 0   2015          AUS         3.469188          0.610997
# 1   2014          AUS         4.306384          1.537726
# 2   2013          AUS         3.425824         -0.048833
# 3   2012          AUS         3.722172          0.372774
# 4   2011          AUS         4.693724          0.590745
# 5   2010          AUS         3.072119          1.576474
# 6   2009          AUS         3.091518          1.235587
# 7   2008          AUS         4.284650          3.025409
# 8   2007          AUS         5.209250          1.690398
# 9   2006          AUS         4.095024          3.227987
# 10  2005          AUS        -3.618815         -4.717772
# 11  2004          AUS         7.005444          1.597584
# 12  2003          AUS         1.926147          3.986776
# 13  2002          AUS         3.713762          1.767229
# 14  2001          AUS         2.832402          3.536383
# 15  2000          AUS         3.586745          0.986223
#
#     Domestic health expenditure  Expense on Goods & Services  \
# 0                      6.353409                    26.756354
# 1                      6.087821                    26.270761
# 2                      5.916563                    25.896647
# 3                      5.859168                    26.143046
# 4                      5.911898                    26.031856
# 5                      5.786625                    26.768833
# 6                      5.933924                    26.493777
# 7                      5.696407                    24.370410
# 8                      5.591425                    24.501630
# 9                      5.457375                    24.977871
# 10                     5.465395                    25.639466
# 11                     5.542416                    25.696281
# 12                     5.379015                    25.773322
# 13                     5.416837                    26.433438
# 14                     5.214668                    26.264917
# 15                     5.206260                    24.083919
#
#     Final consumption expenditure  Agriculture,forestry,fishing   Edu Exp  \
# 0                       75.253985                      2.372644  5.311960
# 1                       73.681945                      2.216224  5.164770
# 2                       73.400238                      2.278906  5.229740
# 3                       72.506066                      2.254748  4.869000
# 4                       72.526546                      2.276542  5.074510
# 5                       74.178362                      2.197568  5.550060
# 6                       72.392225                      2.291720  5.085820
# 7                       73.882561                      2.338630  4.637760
# 8                       74.072813                      2.201100  4.660890
# 9                       74.211836                      2.726734  4.750200
# 10                      75.182004                      2.883330  4.910300
# 11                      75.542107                      3.062114  5.030089
# 12                      76.089568                      2.888534  5.088101
# 13                      75.514980                      3.948012  5.084335
# 14                      76.433979                      3.503360  5.018791
# 15                      75.851648                      3.119068  4.891470
#
#     Research and development expenditure  GDP per Capita after 4 years
# 0                               1.919430                      0.714301
# 1                               2.086668                      0.714301
# 2                               2.178700                      0.626621
# 3                               2.195525                      0.518047
# 4                               2.237650                      0.697917
# 5                               2.375860                      0.850493
# 6                               2.431817                      1.000000
# 7                               2.403700                      0.996342
# 8                               2.319410                      0.850680
# 9                               2.185520                      0.572422
# 10                              2.008604                      0.327197
# 11                              1.854560                      0.508252
# 12                              1.789283                      0.279150
# 13                              1.751610                      0.148842
# 14                              1.680376                      0.094608
# 15                              1.575580                      0.000000

# %%
#Using OLS for finding the p value and t statistics 
import statsmodels.api as sm
import statsmodels.formula.api as smf
#model = sm.OLS(df_joined['GDP per Capita after 4 years'], df_joined[['FDI net inflows','FDI net outflows','Domestic health expenditure','Expense on Goods & Services', 'Final consumption expenditure','Agriculture,forestry,fishing','Edu Exp','Research and development expenditure']]).fit()

# Print out the statisti

model_ave_gdp_ppp_log_lux = smf.ols(formula='GDP per Capita after 4 years ~ FDI net inflows + FDI net outflows + Domestic health expenditure + Edu Exp + Research and development expenditure', data=df_joined).fit()
model_ave_gdp_ppp_log_lux.summary()
model.summary()
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\prana\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-139-704c6eec223a>", line 8, in <module>
#     model_ave_gdp_ppp_log_lux = smf.ols(formula='GDP per Capita after 4 years ~ FDI net inflows + FDI net outflows + Domestic health expenditure + Edu Exp + Research and development expenditure', data=df_joined).fit()
#
#   File "C:\Users\prana\Anaconda3\lib\site-packages\statsmodels\base\model.py", line 159, in from_formula
#     missing=missing)
#
#   File "C:\Users\prana\Anaconda3\lib\site-packages\statsmodels\formula\formulatools.py", line 65, in handle_formula_data
#     NA_action=na_action)
#
#   File "C:\Users\prana\Anaconda3\lib\site-packages\patsy\highlevel.py", line 310, in dmatrices
#     NA_action, return_type)
#
#   File "C:\Users\prana\Anaconda3\lib\site-packages\patsy\highlevel.py", line 165, in _do_highlevel_design
#     NA_action)
#
#   File "C:\Users\prana\Anaconda3\lib\site-packages\patsy\highlevel.py", line 70, in _try_incr_builders
#     NA_action)
#
#   File "C:\Users\prana\Anaconda3\lib\site-packages\patsy\build.py", line 689, in design_matrix_builders
#     factor_states = _factors_memorize(all_factors, data_iter_maker, eval_env)
#
#   File "C:\Users\prana\Anaconda3\lib\site-packages\patsy\build.py", line 354, in _factors_memorize
#     which_pass = factor.memorize_passes_needed(state, eval_env)
#
#   File "C:\Users\prana\Anaconda3\lib\site-packages\patsy\eval.py", line 474, in memorize_passes_needed
#     subset_names = [name for name in ast_names(self.code)
#
#   File "C:\Users\prana\Anaconda3\lib\site-packages\patsy\eval.py", line 474, in <listcomp>
#     subset_names = [name for name in ast_names(self.code)
#
#   File "C:\Users\prana\Anaconda3\lib\site-packages\patsy\eval.py", line 105, in ast_names
#     for node in ast.walk(ast.parse(code)):
#
#   File "C:\Users\prana\Anaconda3\lib\ast.py", line 35, in parse
#     return compile(source, filename, mode, PyCF_ONLY_AST)
#
#   File "<unknown>", line 1
#     Domestic health expenditure
#                   ^
# SyntaxError: invalid syntax

# %%
model_ave_gdp_ppp_log_lux = smf.ols(formula='ave_result ~ gdp_ppp_log', data=pisa_ave_gdp_ppp_log_lux).fit()
model_ave_gdp_ppp_log_lux.summary()

# %% [markdown]
# #### For any modelling task, the hypothesis is that there is some correlation between the features and the target. The null hypothesis is therefore the opposite: there is no correlation between the features and the target.

# %% [markdown]
# Considering the significance value of 0.05.
#
# 1. The **FDI net inflows** has the p-value 0.919, which is greater and this provides less evidence against the null hypothesis and it    is not a significant feature.
# 2.  The **FDI net outflows** has the p-value 0.783, which is greater and this provides less evidence against the null hypothesis and it    is not a significant feature.
# 2. The **Domestic health expenditure** has the p-value 	0.607, which is greater and this provides less evidence against the null hypothesis and it    is not a significant feature.
# 3. The **Expense on Goods & Services** has the p-value 0.438, which is greater and this provides less evidence against the null hypothesis and it    is not a significant feature.
# 4. The **Final consumption expenditure** has the p-value 0.007, which is less and this provides greater evidence against the null hypothesis and      it is a significant feature.
# 5. The **Agriculture,forestry,fishing** has the p-value 0.566, which is less and this provides greater evidence against the null hypothesis and      it is a significant feature.
# 6. The **Education expenditure** has the p-value 0.444, which is less and this provides greater evidence against the null hypothesis and      it is a significant feature.
# 7. The **Research and development expenditure** has the p-value 0.016, which is less and this provides greater evidence against the null hypothesis and      it is a significant feature.

# %% [markdown]
# ### ```OLS linear regression```

# %% [markdown]
# Data is split into 3 parts
#
# Taining data set = 80.75%
#
# Validation data set = 14.25%
#
# Test data set = 5%

# %%
from sklearn.model_selection import  train_test_split
from sklearn import preprocessing

X = df_joined[['Final consumption expenditure','Research and development expenditure']]

y = df_joined['GDP per Capita after 2 years']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=1)

#X_train, X_val, y_train, y_val = train_test_split(X_t, y_t, test_size=0.15, random_state=1)

# %%
from sklearn.model_selection import  train_test_split
from sklearn.metrics import r2_score 
from sklearn.linear_model import LinearRegression
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(X_train,y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_train)

# %%
#training Data
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'% mean_squared_error(y_train, y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'% r2_score(y_train, y_pred))
# Out:
# Coefficients:
#  [-0.08709587  0.65877733]
# Mean squared error: 0.02
# Coefficient of determination: 0.77

# %%
# Make predictions using the testing set
y_pred = regr.predict(X_test)

# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'% mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'% r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [-0.08709587  0.65877733]
# Mean squared error: 0.01
# Coefficient of determination: 0.85

# %%
y_pred
# Out:
# array([0.82231319, 0.26780806, 0.83956706, 0.73335051])

# %%
# Get R2 measure (indicator of accuracy 1 is perfect 0 is horrible)
regr.score(X_test, y_test)
# Out:
# 0.851048516467806

# %% [markdown]
# ### Random forest

# %%
from sklearn.ensemble import RandomForestRegressor


random_model = RandomForestRegressor(n_estimators =100,
 min_samples_split = 10,
 min_samples_leaf = 15,
 max_features= 'auto',
 max_depth = 20,
 bootstrap = True)
random_model.fit(X_train, y_train)
r2_score(y_train, random_model.predict(X_train))
# Out:
# -0.0002590053545932225

# %%
print('R2 score for training data' ,r2_score(y_train, random_model.predict(X_train)))
print('R2 score for validation data',r2_score(y_test, random_model.predict(X_test)))

      
print('Root mean square error score on training set',np.sqrt(mean_squared_error(y_train,random_model.predict(X_train))))
print('Root mean square error score on validation set',np.sqrt(mean_squared_error(y_test,random_model.predict(X_test))))
# Out:
# R2 score for training data -0.0002590053545932225
# R2 score for validation data -0.16144762661451106
# Root mean square error score on training set 0.3178639142822598
# Root mean square error score on validation set 0.27194346117429774
