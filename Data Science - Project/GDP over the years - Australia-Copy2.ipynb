# %%
import wbdata
import pandas as pd
import pycountry
import wbdata
import datetime
import matplotlib.pyplot as plt

 

countries = ["AUS"]

indicators1 = { 
               'BX.KLT.DINV.WD.GD.ZS': 'FDI net inflows',
               'BM.KLT.DINV.WD.GD.ZS':'FDI net outflows',
              'SH.XPD.GHED.GD.ZS': 'Domestic health expenditure',
              'GC.XPN.TOTL.GD.ZS': 'Expense',
              'NE.CON.TOTL.ZS': 'Final consumption expenditure'
              }

data_date = (datetime.datetime(2000, 1, 1), datetime.datetime(2015, 1, 1))
 
 
df1 = wbdata.get_dataframe(indicators1, country=countries, data_date=data_date ,convert_date=False)

# %%
df1
# Out:
#       FDI net inflows  FDI net outflows  Domestic health expenditure  \
# date
# 2015         3.469188          0.610997                     6.353409
# 2014         4.306384          1.537726                     6.087821
# 2013         3.425824         -0.048833                     5.916563
# 2012         3.722172          0.372774                     5.859168
# 2011         4.693724          0.590745                     5.911898
# 2010         3.072119          1.576474                     5.786625
# 2009         3.091518          1.235587                     5.933924
# 2008         4.284650          3.025409                     5.696407
# 2007         5.209250          1.690398                     5.591425
# 2006         4.095024          3.227987                     5.457375
# 2005        -3.618815         -4.717772                     5.465395
# 2004         7.005444          1.597584                     5.542416
# 2003         1.926147          3.986776                     5.379015
# 2002         3.713762          1.767229                     5.416837
# 2001         2.832402          3.536383                     5.214668
# 2000         3.586745          0.986223                     5.206260
#
#         Expense  Final consumption expenditure
# date
# 2015  26.756354                      75.253985
# 2014  26.270761                      73.681945
# 2013  25.896647                      73.400238
# 2012  26.143046                      72.506066
# 2011  26.031856                      72.526546
# 2010  26.768833                      74.178362
# 2009  26.493777                      72.392225
# 2008  24.370410                      73.882561
# 2007  24.501630                      74.072813
# 2006  24.977871                      74.211836
# 2005  25.639466                      75.182004
# 2004  25.696281                      75.542107
# 2003  25.773322                      76.089568
# 2002  26.433438                      75.514980
# 2001  26.264917                      76.433979
# 2000  24.083919                      75.851648

# %%
df1.insert(0, "Country code","AUS")

# %%
df1
# Out:
#      Country code  FDI net inflows  FDI net outflows  \
# date
# 2015          AUS         3.469188          0.610997
# 2014          AUS         4.306384          1.537726
# 2013          AUS         3.425824         -0.048833
# 2012          AUS         3.722172          0.372774
# 2011          AUS         4.693724          0.590745
# 2010          AUS         3.072119          1.576474
# 2009          AUS         3.091518          1.235587
# 2008          AUS         4.284650          3.025409
# 2007          AUS         5.209250          1.690398
# 2006          AUS         4.095024          3.227987
# 2005          AUS        -3.618815         -4.717772
# 2004          AUS         7.005444          1.597584
# 2003          AUS         1.926147          3.986776
# 2002          AUS         3.713762          1.767229
# 2001          AUS         2.832402          3.536383
# 2000          AUS         3.586745          0.986223
#
#       Domestic health expenditure    Expense  Final consumption expenditure
# date
# 2015                     6.353409  26.756354                      75.253985
# 2014                     6.087821  26.270761                      73.681945
# 2013                     5.916563  25.896647                      73.400238
# 2012                     5.859168  26.143046                      72.506066
# 2011                     5.911898  26.031856                      72.526546
# 2010                     5.786625  26.768833                      74.178362
# 2009                     5.933924  26.493777                      72.392225
# 2008                     5.696407  24.370410                      73.882561
# 2007                     5.591425  24.501630                      74.072813
# 2006                     5.457375  24.977871                      74.211836
# 2005                     5.465395  25.639466                      75.182004
# 2004                     5.542416  25.696281                      75.542107
# 2003                     5.379015  25.773322                      76.089568
# 2002                     5.416837  26.433438                      75.514980
# 2001                     5.214668  26.264917                      76.433979
# 2000                     5.206260  24.083919                      75.851648

# %%
df1.reset_index(inplace = True)

# %%
df1
# Out:
#     date Country code  FDI net inflows  FDI net outflows  \
# 0   2015          AUS         3.469188          0.610997
# 1   2014          AUS         4.306384          1.537726
# 2   2013          AUS         3.425824         -0.048833
# 3   2012          AUS         3.722172          0.372774
# 4   2011          AUS         4.693724          0.590745
# 5   2010          AUS         3.072119          1.576474
# 6   2009          AUS         3.091518          1.235587
# 7   2008          AUS         4.284650          3.025409
# 8   2007          AUS         5.209250          1.690398
# 9   2006          AUS         4.095024          3.227987
# 10  2005          AUS        -3.618815         -4.717772
# 11  2004          AUS         7.005444          1.597584
# 12  2003          AUS         1.926147          3.986776
# 13  2002          AUS         3.713762          1.767229
# 14  2001          AUS         2.832402          3.536383
# 15  2000          AUS         3.586745          0.986223
#
#     Domestic health expenditure    Expense  Final consumption expenditure
# 0                      6.353409  26.756354                      75.253985
# 1                      6.087821  26.270761                      73.681945
# 2                      5.916563  25.896647                      73.400238
# 3                      5.859168  26.143046                      72.506066
# 4                      5.911898  26.031856                      72.526546
# 5                      5.786625  26.768833                      74.178362
# 6                      5.933924  26.493777                      72.392225
# 7                      5.696407  24.370410                      73.882561
# 8                      5.591425  24.501630                      74.072813
# 9                      5.457375  24.977871                      74.211836
# 10                     5.465395  25.639466                      75.182004
# 11                     5.542416  25.696281                      75.542107
# 12                     5.379015  25.773322                      76.089568
# 13                     5.416837  26.433438                      75.514980
# 14                     5.214668  26.264917                      76.433979
# 15                     5.206260  24.083919                      75.851648

# %%
#grab indicators above for countires above and load into data frame
#df = wbdata.get_dataframe(indicators, country=countries, data_date=data_date ,convert_date=False)

data_date = (datetime.datetime(2002, 1, 1), datetime.datetime(2017, 1, 1))
indicators2 = {'NY.GDP.PCAP.CD': 'GDP per Capita after 2 years'}

# %%
#grab indicators above for countires above and load into data frame
df2 = wbdata.get_dataframe(indicators2, country=countries, data_date=data_date ,convert_date=False)

# %%
df2
# Out:
#       GDP per Capita after 2 years
# date
# 2017                  54066.471269
# 2016                  49971.131456
# 2015                  56755.721712
# 2014                  62510.791171
# 2013                  68150.107041
# 2012                  68012.147901
# 2011                  62517.833747
# 2010                  52022.125596
# 2009                  42772.359166
# 2008                  49601.656708
# 2007                  40960.054495
# 2006                  36044.922811
# 2005                  33999.242858
# 2004                  30430.676437
# 2003                  23447.031001
# 2002                  20082.483267

# %%
df2.reset_index(inplace = True)

# %%
df2 = df2.drop(['date'],axis = 1)

# %%
df2
# Out:
#     GDP per Capita after 2 years
# 0                   54066.471269
# 1                   49971.131456
# 2                   56755.721712
# 3                   62510.791171
# 4                   68150.107041
# 5                   68012.147901
# 6                   62517.833747
# 7                   52022.125596
# 8                   42772.359166
# 9                   49601.656708
# 10                  40960.054495
# 11                  36044.922811
# 12                  33999.242858
# 13                  30430.676437
# 14                  23447.031001
# 15                  20082.483267

# %%
#Get GDP after 3 years

data_date = (datetime.datetime(2003, 1, 1), datetime.datetime(2018, 1, 1))

#grab indicators above for countires above and load into data frame
#df3 = wbdata.get_dataframe(indicators, country=countries, data_date=data_date ,convert_date=False)

indicators3 = {'NY.GDP.PCAP.CD': 'GDP per Capita after 3 years'}

# %%
#grab indicators above for countires above and load into data frame
df3 = wbdata.get_dataframe(indicators3, country=countries, data_date=data_date ,convert_date=False)

# %%
df3.reset_index(inplace = True)

# %%
df3 = df3.drop(['date'],axis = 1)

# %%
#Get GDP after 4 years

data_date = (datetime.datetime(2004, 1, 1), datetime.datetime(2019, 1, 1))



indicators4 = {'NY.GDP.PCAP.CD': 'GDP per Capita after 4 years'}

# %%
#grab indicators above for countires above and load into data frame
df4 = wbdata.get_dataframe(indicators4, country=countries, data_date=data_date ,convert_date=False)

# %%
df4.reset_index(inplace = True)

# %%
df4 = df4.drop(['date'],axis = 1)

# %%
df4
# Out:
#     GDP per Capita after 4 years
# 0                            NaN
# 1                   57373.686684
# 2                   54066.471269
# 3                   49971.131456
# 4                   56755.721712
# 5                   62510.791171
# 6                   68150.107041
# 7                   68012.147901
# 8                   62517.833747
# 9                   52022.125596
# 10                  42772.359166
# 11                  49601.656708
# 12                  40960.054495
# 13                  36044.922811
# 14                  33999.242858
# 15                  30430.676437

# %%
df3
# Out:
#     GDP per Capita after 3 years
# 0                   57373.686684
# 1                   54066.471269
# 2                   49971.131456
# 3                   56755.721712
# 4                   62510.791171
# 5                   68150.107041
# 6                   68012.147901
# 7                   62517.833747
# 8                   52022.125596
# 9                   42772.359166
# 10                  49601.656708
# 11                  40960.054495
# 12                  36044.922811
# 13                  33999.242858
# 14                  30430.676437
# 15                  23447.031001

# %%
df4
# Out:
#     GDP per Capita after 4 years
# 0                            NaN
# 1                   57373.686684
# 2                   54066.471269
# 3                   49971.131456
# 4                   56755.721712
# 5                   62510.791171
# 6                   68150.107041
# 7                   68012.147901
# 8                   62517.833747
# 9                   52022.125596
# 10                  42772.359166
# 11                  49601.656708
# 12                  40960.054495
# 13                  36044.922811
# 14                  33999.242858
# 15                  30430.676437

# %%
# replacing na values in college with No college 
#nba["College"].fillna("No College", inplace = True)
df4 = df4["GDP per Capita after 4 years"].fillna("57373.7")

# %%
df_joined = pd.merge(df1,df2,left_index=True, right_index=True)
df_joined
# Out:
#     date Country code  FDI net inflows  FDI net outflows  \
# 0   2015          AUS         3.469188          0.610997
# 1   2014          AUS         4.306384          1.537726
# 2   2013          AUS         3.425824         -0.048833
# 3   2012          AUS         3.722172          0.372774
# 4   2011          AUS         4.693724          0.590745
# 5   2010          AUS         3.072119          1.576474
# 6   2009          AUS         3.091518          1.235587
# 7   2008          AUS         4.284650          3.025409
# 8   2007          AUS         5.209250          1.690398
# 9   2006          AUS         4.095024          3.227987
# 10  2005          AUS        -3.618815         -4.717772
# 11  2004          AUS         7.005444          1.597584
# 12  2003          AUS         1.926147          3.986776
# 13  2002          AUS         3.713762          1.767229
# 14  2001          AUS         2.832402          3.536383
# 15  2000          AUS         3.586745          0.986223
#
#     Domestic health expenditure    Expense  Final consumption expenditure  \
# 0                      6.353409  26.756354                      75.253985
# 1                      6.087821  26.270761                      73.681945
# 2                      5.916563  25.896647                      73.400238
# 3                      5.859168  26.143046                      72.506066
# 4                      5.911898  26.031856                      72.526546
# 5                      5.786625  26.768833                      74.178362
# 6                      5.933924  26.493777                      72.392225
# 7                      5.696407  24.370410                      73.882561
# 8                      5.591425  24.501630                      74.072813
# 9                      5.457375  24.977871                      74.211836
# 10                     5.465395  25.639466                      75.182004
# 11                     5.542416  25.696281                      75.542107
# 12                     5.379015  25.773322                      76.089568
# 13                     5.416837  26.433438                      75.514980
# 14                     5.214668  26.264917                      76.433979
# 15                     5.206260  24.083919                      75.851648
#
#     GDP per Capita after 2 years
# 0                   54066.471269
# 1                   49971.131456
# 2                   56755.721712
# 3                   62510.791171
# 4                   68150.107041
# 5                   68012.147901
# 6                   62517.833747
# 7                   52022.125596
# 8                   42772.359166
# 9                   49601.656708
# 10                  40960.054495
# 11                  36044.922811
# 12                  33999.242858
# 13                  30430.676437
# 14                  23447.031001
# 15                  20082.483267

# %%
df_joined1 = pd.merge(df_joined ,df3,left_index=True, right_index=True)

# %%
df_joined2 = pd.merge(df_joined1 ,df4,left_index=True, right_index=True)

# %%
df_joined2
# Out:
#     date Country code       FDI  Manufacturing  Electricity from Natural Gas  \
# 0   2015          AUS  3.469188       6.290283                     20.795478
# 1   2014          AUS  4.306384       6.358217                     21.909741
# 2   2013          AUS  3.425824       6.597965                     20.452606
# 3   2012          AUS  3.722172       7.030140                     19.343072
# 4   2011          AUS  4.693724       7.351573                     19.297223
# 5   2010          AUS  3.072119       7.989865                     17.646873
# 6   2009          AUS  3.091518       8.440060                     16.151877
# 7   2008          AUS  4.284650       9.195600                     14.380454
# 8   2007          AUS  5.209250       9.280844                     13.107717
# 9   2006          AUS  4.095024       9.886796                      9.765090
# 10  2005          AUS -3.618815      10.336080                     10.424048
# 11  2004          AUS  7.005444      10.890447                     13.548308
# 12  2003          AUS  1.926147      10.870331                     13.317255
# 13  2002          AUS  3.713762      10.559587                     13.954736
# 14  2001          AUS  2.832402      11.003225                      7.701157
# 15  2000          AUS  3.586745      11.593732                      7.740727
#
#     Employment in Services  Domestic health expenditure  Health per capita  \
# 0                77.970001                  1553.928467        4887.800781
# 1                76.915001                  1840.211426        5637.566895
# 2                76.930000                  1894.448853        5838.413574
# 3                76.494003                  1963.122070        6047.057617
# 4                76.348000                  1809.308594        5876.865723
# 5                75.792999                  1553.358765        4952.777344
# 6                75.625000                  1227.402832        3997.537109
# 7                75.068001                  1267.558472        4088.778076
# 8                75.294998                  1164.531006        3794.251709
# 9                75.125000                  1007.032959        3177.460693
# 10               75.286003                   949.236450        3004.114746
# 11               75.022003                   872.931946        2757.631836
# 12               75.204002                   715.982544        2240.952148
# 13               74.703003                   553.352539        1763.740723
# 14               74.505997                   502.415558        1558.187378
# 15               73.527000                   516.179810        1632.427612
#
#     GDP per Capita after 2 years  GDP per Capita after 3 years  \
# 0                   54066.471269                  57373.686684
# 1                   49971.131456                  54066.471269
# 2                   56755.721712                  49971.131456
# 3                   62510.791171                  56755.721712
# 4                   68150.107041                  62510.791171
# 5                   68012.147901                  68150.107041
# 6                   62517.833747                  68012.147901
# 7                   52022.125596                  62517.833747
# 8                   42772.359166                  52022.125596
# 9                   49601.656708                  42772.359166
# 10                  40960.054495                  49601.656708
# 11                  36044.922811                  40960.054495
# 12                  33999.242858                  36044.922811
# 13                  30430.676437                  33999.242858
# 14                  23447.031001                  30430.676437
# 15                  20082.483267                  23447.031001
#
#    GDP per Capita after 4 years
# 0                       57373.7
# 1                       57373.7
# 2                       54066.5
# 3                       49971.1
# 4                       56755.7
# 5                       62510.8
# 6                       68150.1
# 7                       68012.1
# 8                       62517.8
# 9                       52022.1
# 10                      42772.4
# 11                      49601.7
# 12                      40960.1
# 13                      36044.9
# 14                      33999.2
# 15                      30430.7

# %%
df_joined.corr()
# Out:
#                                FDI net inflows  FDI net outflows  \
# FDI net inflows                       1.000000          0.619189
# FDI net outflows                      0.619189          1.000000
# Domestic health expenditure           0.180350         -0.208782
# Expense                              -0.121748         -0.108949
# Final consumption expenditure        -0.196824          0.181356
# GDP per Capita after 2 years          0.095982         -0.184614
#
#                                Domestic health expenditure   Expense  \
# FDI net inflows                                   0.180350 -0.121748
# FDI net outflows                                 -0.208782 -0.108949
# Domestic health expenditure                       1.000000  0.492128
# Expense                                           0.492128  1.000000
# Final consumption expenditure                    -0.620497 -0.125922
# GDP per Capita after 2 years                      0.773776  0.383659
#
#                                Final consumption expenditure  \
# FDI net inflows                                    -0.196824
# FDI net outflows                                    0.181356
# Domestic health expenditure                        -0.620497
# Expense                                            -0.125922
# Final consumption expenditure                       1.000000
# GDP per Capita after 2 years                       -0.856356
#
#                                GDP per Capita after 2 years
# FDI net inflows                                    0.095982
# FDI net outflows                                  -0.184614
# Domestic health expenditure                        0.773776
# Expense                                            0.383659
# Final consumption expenditure                     -0.856356
# GDP per Capita after 2 years                       1.000000

# %%
import seaborn as sns
#plotting the heat map of the correlation
plt.figure(figsize=(20,7))
sns.heatmap(df_joined.corr(), annot=True)

# %%
#Using OLS for finding the p value and t statistics 
import statsmodels.api as sm

model = sm.OLS(df_joined['GDP per Capita after 2 years'], df_joined[['FDI net inflows', 'FDI net outflows', 'Domestic health expenditure','Expense', 'Final consumption expenditure']]).fit()

# Print out the statistics
model.summary()
# Out:
# C:\Users\prana\Anaconda3\lib\site-packages\scipy\stats\stats.py:1535: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=16
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       OLS Regression Results
# =================================================================================================
# Dep. Variable:     GDP per Capita after 2 years   R-squared (uncentered):                   0.976
# Model:                                      OLS   Adj. R-squared (uncentered):              0.965
# Method:                           Least Squares   F-statistic:                              89.35
# Date:                          Fri, 17 Apr 2020   Prob (F-statistic):                    1.59e-08
# Time:                                  12:57:02   Log-Likelihood:                         -165.74
# No. Observations:                            16   AIC:                                      341.5
# Df Residuals:                                11   BIC:                                      345.3
# Df Model:                                     5
# Covariance Type:                      nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# FDI net inflows                -570.6193   1592.305     -0.358      0.727   -4075.260    2934.021
# FDI net outflows                490.2071   1721.261      0.285      0.781   -3298.263    4278.677
# Domestic health expenditure    3.083e+04      1e+04      3.075      0.011    8759.051    5.29e+04
# Expense                        2734.6553   3488.746      0.784      0.450   -4944.024    1.04e+04
# Final consumption expenditure -2649.9118    843.066     -3.143      0.009   -4505.488    -794.335
# ==============================================================================
# Omnibus:                        0.078   Durbin-Watson:                   0.738
# Prob(Omnibus):                  0.962   Jarque-Bera (JB):                0.297
# Skew:                          -0.078   Prob(JB):                        0.862
# Kurtosis:                       2.351   Cond. No.                         358.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# #### For any modelling task, the hypothesis is that there is some correlation between the features and the target. The null hypothesis is therefore the opposite: there is no correlation between the features and the target.

# %% [markdown]
# Considering the significance value of 0.05.
#
# 1. The **FDI** has the p-value 0.419, which is greater and this provides less evidence against the null hypothesis and it    is not a significant feature.
# 2. The **Manufacturing** has the p-value 0.896, which is greater and this provides less evidence against the null hypothesis and it    is not a significant feature.
# 3. The **Electricity from Natural Gas** has the p-value 0.871,which is greater and this provides less evidence against the null hypothesis and it    is not a significant feature.
# 4. The **Employment in Services** has the p-value 0.874, which is greater and this provides less evidence against the null hypothesis and it    is not a significant feature.
# 5. The **Domestic health expenditure** has the p-value 0.021, which is less and this provides greater evidence against the null hypothesis and      it is a significant feature.
# 6. The **Health per capita** has the p-value 0.008, which is less and this provides greater evidence against the null hypothesis and      it is a significant feature.

# %% [markdown]
# ### ```OLS linear regression```

# %% [markdown]
# Data is split into 3 parts
#
# Taining data set = 80.75%
#
# Validation data set = 14.25%
#
# Test data set = 5%

# %%
from sklearn.model_selection import  train_test_split
from sklearn import preprocessing

X = df_joined[ ['Domestic health expenditure', 'Final consumption expenditure']]

y = df_joined['GDP per Capita after 2 years']

X_t, X_test, y_t, y_test = train_test_split(X, y, test_size=0.05, random_state=1)

X_train, X_val, y_train, y_val = train_test_split(X_t, y_t, test_size=0.15, random_state=1)

X_scaled = preprocessing.scale(X_train)
X_scaled
# Out:
# array([[ 0.91586246, -1.18801674],
#        [-0.62503299, -0.41168369],
#        [-0.598121  ,  0.51632896],
#        [ 0.17708396, -0.72665119],
#        [-0.33965934,  0.860785  ],
#        [-0.76106557,  0.83483673],
#        [ 0.47982765, -0.44370389],
#        [-1.46769545,  1.15687677],
#        [ 2.38178111,  0.58518295],
#        [-0.88798498,  1.38445805],
#        [-0.1752034 , -0.54466631],
#        [ 0.90020755, -2.02374663]])

# %%
from sklearn.model_selection import  train_test_split
from sklearn.metrics import r2_score 
from sklearn.linear_model import LinearRegression
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(X_train,y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_train)

# %%
#training Data
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'% mean_squared_error(y_train, y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'% r2_score(y_train, y_pred))
# Out:
# Coefficients:
#  [21930.52364013 -8008.80408445]
# Mean squared error: 35337559.63
# Coefficient of determination: 0.82

# %%
# Make predictions using the testing set
y_pred = regr.predict(X_val)

# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'% mean_squared_error(y_val, y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'% r2_score(y_val, y_pred))
# Out:
# Coefficients:
#  [21930.52364013 -8008.80408445]
# Mean squared error: 82526208.26
# Coefficient of determination: 0.69
